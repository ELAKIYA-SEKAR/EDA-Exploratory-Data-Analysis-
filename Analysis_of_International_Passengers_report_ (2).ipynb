# %% [markdown]
# **EXPLORATORY** **DATA** **ANALYSIS**

# %%
import pandas as pd
import seaborn as sd
import numpy as np
import matplotlib.pyplot as plt

# %%
passen=pd.read_csv("/content/International_Report_Passengers.csv")

# %%
passengers=passen.head(1000)
passengers
# Out:
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0    05/01/2014  2014      5       14492     RDU       36      11032    CUN
# 1    06/01/2007  2007      6       13204     MCO       33      16085    YHZ
# 2    12/01/2005  2005     12       11433     DTW       43      10411    AUA
# 3    04/01/2003  2003      4       13487     MSP       63      16304    ZIH
# 4    12/01/2005  2005     12       12016     GUM        5      11138    CRK
# ..          ...   ...    ...         ...     ...      ...        ...    ...
# 995  06/01/2003  2003      6       11423     DSM       61      16217    YUL
# 996  12/01/2006  2006     12       11433     DTW       43      16257    YYC
# 997  04/01/2005  2005      4       13495     MSY       72      11032    CUN
# 998  02/01/2001  2001      2       13930     ORD       41      13605    NAS
# 999  04/01/2001  2001      4       13303     MIA       33      14739    SDQ
#
# ...

# %%
passengers.tail()
# Out:
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 995  06/01/2003  2003      6       11423     DSM       61      16217    YUL
# 996  12/01/2006  2006     12       11433     DTW       43      16257    YYC
# 997  04/01/2005  2005      4       13495     MSY       72      11032    CUN
# 998  02/01/2001  2001      2       13930     ORD       41      13605    NAS
# 999  04/01/2001  2001      4       13303     MIA       33      14739    SDQ
#
#      fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 995     941      19531      AC           0.0  Passengers        0.0     52.0
# 996     916      20305     PCQ           1.0  Passengers        0.0     43.0
# 997     148      20402      GL           1.0  Passengers        0.0    160.0
# 998     204      20344     RYQ           1.0  Passengers        0.0   1207.0
# 999     224      20016     LGQ           0.0  Passengers        0.0   2844.0
#
#       Total
# 995    52.0
# 996    43.0
# ...

# %%
passengers.describe()
# Out:
#              Year        Month   usg_apt_id      usg_wac     fg_apt_id  \
# count  1000.00000  1000.000000   1000.00000  1000.000000   1000.000000
# mean   2005.31800     6.195000  13061.77200    41.903000  13536.795000
# std       2.83671     3.603604   4990.41416    24.557497   2029.651309
# min    2001.00000     1.000000  10135.00000     1.000000  10148.000000
# 25%    2003.00000     3.000000  11433.00000    23.000000  11503.750000
# 50%    2005.00000     6.000000  13198.00000    34.000000  13605.000000
# 75%    2008.00000    10.000000  13930.00000    63.000000  15513.000000
# max    2014.00000    12.000000  99999.00000    93.000000  16322.000000
#
#             fg_wac     airlineid  carriergroup  Scheduled       Charter  \
# count  1000.000000   1000.000000   1000.000000     1000.0   1000.000000
# mean    431.225000  20276.240000      0.671000        0.0    947.464000
# std     304.111746    385.588583      0.470085        0.0   1836.175563
# ...

# %%
passengers.shape
# Out:
# (1000, 16)

# %%
passengers.isnull()
# Out:
#      data_dte   Year  Month  usg_apt_id  usg_apt  usg_wac  fg_apt_id  fg_apt  \
# 0       False  False  False       False    False    False      False   False
# 1       False  False  False       False    False    False      False   False
# 2       False  False  False       False    False    False      False   False
# 3       False  False  False       False    False    False      False   False
# 4       False  False  False       False    False    False      False   False
# ..        ...    ...    ...         ...      ...      ...        ...     ...
# 995     False  False  False       False    False    False      False   False
# 996     False  False  False       False    False    False      False   False
# 997     False  False  False       False    False    False      False   False
# 998     False  False  False       False    False    False      False   False
# 999     False  False  False       False    False    False      False   False
#
# ...

# %%
passengers.isnull().sum()
# Out:
# data_dte         0
# Year             0
# Month            0
# usg_apt_id       0
# usg_apt          0
# usg_wac          0
# fg_apt_id        0
# fg_apt           0
# fg_wac           0
# airlineid        0
# carrier         18
# carriergroup     0
# type             0
# Scheduled        0
# Charter          0
# Total            0
# dtype: int64

# %%
passengers['carrier'].notnull().sum()
# Out:
# 982

# %%
print(passengers.duplicated().sum())
# Out:
# 0

# %%
passengers["Year"].unique()
# Out:
# array([2014, 2007, 2005, 2003, 2001, 2004, 2008, 2010, 2009, 2002, 2006])

# %%
passengers["Year"].value_counts()
# Out:
# 2004    114
# 2003    113
# 2006    107
# 2001    105
# 2005    104
# 2002     97
# 2007     93
# 2010     92
# 2008     89
# 2009     85
# 2014      1
# Name: Year, dtype: int64

# %%
passengers.replace(np.nan, "0.671000", inplace = True)
passengers
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0    05/01/2014  2014      5       14492     RDU       36      11032    CUN
# 1    06/01/2007  2007      6       13204     MCO       33      16085    YHZ
# 2    12/01/2005  2005     12       11433     DTW       43      10411    AUA
# 3    04/01/2003  2003      4       13487     MSP       63      16304    ZIH
# 4    12/01/2005  2005     12       12016     GUM        5      11138    CRK
# ..          ...   ...    ...         ...     ...      ...        ...    ...
# 995  06/01/2003  2003      6       11423     DSM       61      16217    YUL
# ...

# %%
passengers.carriergroup.isnull().sum()
# Out:
# 0

# %%
passengers1 = passengers[passengers["Total"] > 950]
passengers1
# Out:
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 2    12/01/2005  2005     12       11433     DTW       43      10411    AUA
# 13   03/01/2004  2004      3       11193     CVG       52      11731    FPO
# 14   02/01/2004  2004      2       12889     LAS       85      16042    YEG
# 17   11/01/2003  2003     11       12892     LAX       91      14228    PPT
# 23   11/01/2006  2006     11       11292     DEN       82      11032    CUN
# ..          ...   ...    ...         ...     ...      ...        ...    ...
# 988  05/01/2005  2005      5       13930     ORD       41      11032    CUN
# 989  04/01/2004  2004      4       14307     PVD       15      11731    FPO
# 992  01/01/2002  2002      1       11298     DFW       74      11032    CUN
# 998  02/01/2001  2001      2       13930     ORD       41      13605    NAS
# 999  04/01/2001  2001      4       13303     MIA       33      14739    SDQ
#
# ...

# %%
passengers.boxplot()

# %%
passengers.corr()
# Out:
#                   Year     Month  usg_apt_id   usg_wac  fg_apt_id    fg_wac  \
# Year          1.000000  0.040735    0.044915 -0.069894   0.148709  0.223542
# Month         0.040735  1.000000    0.016608 -0.038358   0.056526  0.133463
# usg_apt_id    0.044915  0.016608    1.000000 -0.065277  -0.007928  0.040908
# usg_wac      -0.069894 -0.038358   -0.065277  1.000000   0.100405 -0.038332
# fg_apt_id     0.148709  0.056526   -0.007928  0.100405   1.000000  0.610821
# fg_wac        0.223542  0.133463    0.040908 -0.038332   0.610821  1.000000
# airlineid     0.198975  0.075345    0.046053 -0.057133  -0.013927 -0.076697
# carriergroup -0.077602 -0.071408    0.009407  0.045097  -0.082797 -0.258410
# Scheduled          NaN       NaN         NaN       NaN        NaN       NaN
# Charter      -0.148932 -0.039241    0.018029  0.023282  -0.184970 -0.185541
# Total        -0.148932 -0.039241    0.018029  0.023282  -0.184970 -0.185541
#
# ...

# %% [markdown]
# **DATA** **VISUALIZATION**

# %%
plt.bar(passengers['Year'],passengers['Total'])
# Out:
# <BarContainer object of 1000 artists>

# %%
plt.plot(passengers['Year'],passengers['Total'])

# %%
plt.pie(passengers['Total'])
plt.xlabel("Total")
plt.show()

# %%
plt.hist(passengers['Total'])
plt.show()

# %%
plt.boxplot(passengers['Total'])
plt.show()

# %%
plt.scatter(passengers['Year'],passengers['Total'])
plt.show()

# %%
plt.stem(passengers['Year'],passengers['Total'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
